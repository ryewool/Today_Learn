# %%
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# %%
print(matplotlib.__version__)
# Out:
# 3.3.2

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4,5], 'o')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = range(0, 100)
y = range(0, 200,2)
plt.plot(x, y)
plt.show()

# %%
import numpy as np
ypoints = np.array([3, 3, 1, 20, 10])
plt.plot(ypoints, marker = 'o')
plt.show()

# %%
plt.plot(ypoints, marker = '*')
plt.show()

# %%
y = np.array([3,3,1,20,10])
plt.plot(y, '*-r', ms=15)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(y, marker="o", ms=9, mfc='r')
plt.show()

# %%
fig = plt.figure(figsize =(30,15))
ax1 = fig.add_subplot(3,3,1)
ax2 = fig.add_subplot(3,3,2)
ax3 = fig.add_subplot(3,3,3)
ax4 = fig.add_subplot(3,3,4)
ax5 = fig.add_subplot(3,3,5)
ax6 = fig.add_subplot(3,3,6)
ax7 = fig.add_subplot(3,3,7)
ax8 = fig.add_subplot(3,3,8)
ax9 = fig.add_subplot(3,3,9)
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)
x=range(0,100)
y=[v*v for v in x]
ax1.plot(x,y)
ax2.bar(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0.0, 2 * np.pi, 0.1)
sin_y = np.sin(x)
cos_y = np.cos(x)
fig = plt.figure()
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)
ax1.plot(x, sin_y, 'b--')
ax2.plot(x, cos_y, 'r--')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0.0, 2 * np.pi, 0.1)
sin_y = np.sin(x)
cos_y = np.cos(x)
tan_y = np.tan(x)
tanh_y = np.tanh(x)
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)
ax1.plot(x, sin_y, 'b--')
ax2.plot(x, cos_y, 'r--')
ax3.plot(x, tan_y, 'g--')
ax4.plot(x, tanh_y, 'y--')
plt.show()

# %%
x = np.arange(10)
plt.plot(x, 1*x, label='y = %ix' % 1)
plt.plot(x, 2*x, label='y = %ix' % 2)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.subplot(3,3,1)
plt.plot(x, 1*x, label='y = %ix' % 1)
plt.legend(loc='upper left')    # 2
plt.subplot(3,3,2)
plt.plot(x, 1*x, label='y = %ix' % 1)
plt.legend(loc='upper center')  # 9
plt.subplot(3,3,3)
plt.plot(x, 1*x, label='y = %ix' % 1)
plt.legend(loc='upper right')  # 1
plt.subplot(3,3,4)
plt.plot(x, 1*x, label='y = %ix' % 1)
plt.legend(loc='center left')  # 6
plt.subplot(3,3,5)
plt.plot(x, 1*x, label='y = %ix' % 1)
plt.legend(loc='center')  # 10
plt.subplot(3,3,6)
plt.plot(x, 1*x, label='y = %ix' % 1)
plt.legend(loc='center right')  # 5
plt.subplot(3,3,7)
plt.plot(x, 1*x, label='y = %ix' % 1)
plt.legend(loc='lower left')  # 3
plt.subplot(3,3,8)
plt.plot(x, 1*x, label='y = %ix' % 1)
plt.legend(loc='lower center')  # 8
plt.subplot(3,3,9)
plt.plot(x, 1*x, label='y = %ix' % 1)
plt.legend(loc='lower right')  # 4

# %%
import os, warnings
warnings.filterwarnings(action='ignore')

# %%
from matplotlib import font_manager, rc
import matplotlib.pyplot as plt
import platform

# %%
rc('font', family='AppleGothic')
matplotlib.rcParams['axes.unicode_minus'] = False

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)
plt.title("스포츠 시청 데이터")
plt.xlabel("평균 혈압")
plt.ylabel("칼로리")
# Out:
# Text(0, 0.5, '칼로리')

# %%
x = np.array([70, 75, 80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([220, 240, 260, 280, 300, 320, 340, 360, 380, 400, 420, 440])
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.plot(x, y)

# %%
import matplotlib.pyplot as plt 
import numpy as np
#plot 1:
x = np.array([0, 1, 2, 3]) 
y = np.array([3, 8, 1, 10])
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")
#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")
plt.suptitle("MY SHOP")
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np
x = np.array([51,71,18,17,21,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)
plt.show()

# %%
x = np.array([51,71,18,17,21,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color='hotpink')
x = np.array([511,711,118,17,21,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color='#88c999') 
plt.show()

# %%
x = np.random.normal(loc=170, scale=10, size=100)  # 평균, 표준편차, 개수
print(x)
plt.hist(x)
# Out:
# [161.58442426 168.2664837  170.12763942 180.53733997 171.49968797
#  173.70031977 166.24390236 166.84444686 170.04860425 172.00689458
#  171.12208132 169.61173807 179.81459062 184.7780516  164.98841421
#  165.1257713  199.78292524 154.63848654 189.30012078 181.13864528
#  176.93203781 160.95127852 172.9382814  166.40075516 173.22295932
#  180.78141448 175.77202902 165.16130042 161.04231824 178.71760374
#  164.86291039 188.81375307 175.78374394 164.77959572 184.62376144
#  173.16809467 156.51065001 155.62673375 154.14414883 179.70842024
#  166.23941995 167.95242804 185.24964703 166.78883601 151.20880375
#  178.94975219 167.51455357 176.4734576  178.90877968 161.36165748
#  171.77122911 178.78725843 166.6317453  172.80123079 180.32370909
#  172.77775612 178.50888526 174.47233053 176.74143238 169.30545198
#  182.37252462 174.37088525 154.71814133 170.06850172 163.5975962
#  177.56333452 175.75929603 167.40198429 178.4370286  163.7818172
#  166.35426843 160.66037551 163.14014913 183.49963133 172.88016828
#  173.42128451 160.29404667 158.15723128 168.64184325 181.16509343
#  171.65203705 177.51646323 166.40081376 162.7310686  158.90592169
#  184.63067932 161.31353098 154.01365321 173.70941706 166.95247686
#  172.13557886 172.82725906 177.931569   178.45980028 155.50237497
#  156.67032962 156.14989077 172.33741809 173.21232968 162.16382295]
# (array([ 7.,  7., 15., 19., 20., 19.,  9.,  3.,  0.,  1.]),
#  array([151.20880375, 156.0662159 , 160.92362805, 165.7810402 ,
#         170.63845235, 175.4958645 , 180.35327665, 185.2106888 ,
#         190.06810095, 194.92551309, 199.78292524]),
#  <BarContainer object of 10 artists>)

# %%
y = np.array([30,20,35,10, 5])
plt.figure(figsize=(10,10))
plt.pie(y)
# Out:
# ([<matplotlib.patches.Wedge at 0x7ffcb5de6190>,
#   <matplotlib.patches.Wedge at 0x7ffcb5de6670>,
#   <matplotlib.patches.Wedge at 0x7ffcb5de6a90>,
#   <matplotlib.patches.Wedge at 0x7ffcb5de6eb0>,
#   <matplotlib.patches.Wedge at 0x7ffcb5df3310>],
#  [Text(0.6465637441936395, 0.8899187180267094, ''),
#   Text(-0.8899187482945419, 0.6465637025335369, ''),
#   Text(-0.49938947630209474, -0.9801072140121813, ''),
#   Text(0.8899187331606258, -0.6465637233635886, ''),
#   Text(1.0864571863351944, -0.1720778377961938, '')])

# %%
myfood = ['banana', 'apple', 'candy']
print(myfood[0])
print(myfood[1])
print(myfood[2])
print(myfood[1:3])  # 첫번째 두번째 가져오기
# Out:
# banana
# apple
# candy
# ['apple', 'candy']

# %%
for item in myfood:
    print(item)
# Out:
# banana
# apple
# candy

# %%
dict1 = {'one':'하나', 'two':"둘", 'three':'셋'}
dict2 = {1:"하나", 2:"둘", 3:"셋"}
dict3 = {'col1':[1,2,3], 'col2':['a','b','c']}

# %%
print(dict1['one'])
print(dict2[2])
print(dict3['col2'])
# Out:
# 하나
# 둘
# ['a', 'b', 'c']

# %%
import pandas as pd

# %%
import pandas as pd
import seaborn as sns
from pandas import Series, DataFrame

# %%
score = Series( [1000, 14000, 3000, 3000, 1000] )
print(score)
print("자료형 확인 : ", type(score))
# Out:
# 0     1000
# 1    14000
# 2     3000
# 3     3000
# 4     1000
# dtype: int64
# 자료형 확인 :  <class 'pandas.core.series.Series'>

# %%
## Series 인덱스 확인
print(score.index)
# 인덱스를 리스트 자료형으로 변경 후, 확인하기
print(list(score.index))
## Series 값 확인
print(score.values)
## Series 값 자료형 확인
print(score.dtype)
# Out:
# RangeIndex(start=0, stop=5, step=1)
# [0, 1, 2, 3, 4]
# [ 1000 14000  3000  3000  1000]
# int64

# %%
### 인덱스(index) 속성 이용 
score = Series( [1000, 14000, 3000], 
               index = ['2019-05-01', '2019-05-02', '2019-05-03'] )  
print(score)
# Out:
# 2019-05-01     1000
# 2019-05-02    14000
# 2019-05-03     3000
# dtype: int64

# %%
week_plan = Series(['팀프로젝트하기','공부하기','과외하기','판다스복습','운동하기'],
                   index = ['Mon','Tue','Wed','Thur','Fri'])
print(week_plan)
# Out:
# Mon     팀프로젝트하기
# Tue        공부하기
# Wed        과외하기
# Thur      판다스복습
# Fri        운동하기
# dtype: object

# %%
print(week_plan['Mon':'Wed'])
# Out:
# Mon    팀프로젝트하기
# Tue       공부하기
# Wed       과외하기
# dtype: object

# %%
print(week_plan[0:2])
# Out:
# Mon    팀프로젝트하기
# Tue       공부하기
# dtype: object

# %%
week_plan.iloc[0:3]
# Out:
# Mon    팀프로젝트하기
# Tue       공부하기
# Wed       과외하기
# dtype: object

# %%
week_plan.loc['Mon':'Fri']
# Out:
# Mon     팀프로젝트하기
# Tue        공부하기
# Wed        과외하기
# Thur      판다스복습
# Fri        운동하기
# dtype: object

# %%
val = ['음악듣기', '책읽기', '맛난것 먹기', '아무것도 안하기', '좋은 사람 만나기']
idx = pd.date_range(start="2021-06-21", end="2021-06-25")

schedule = Series( val, index = idx)

print(schedule['2021-06-21':'2021-06-23'])

print(schedule[0:3])

schedule.iloc[0:3]
# Out:
# 2021-06-21      음악듣기
# 2021-06-22       책읽기
# 2021-06-23    맛난것 먹기
# Freq: D, dtype: object
# 2021-06-21      음악듣기
# 2021-06-22       책읽기
# 2021-06-23    맛난것 먹기
# Freq: D, dtype: object
# 2021-06-21      음악듣기
# 2021-06-22       책읽기
# 2021-06-23    맛난것 먹기
# Freq: D, dtype: object

# %%
for val in schedule.values:
    print(val)
# Out:
# 음악듣기
# 책읽기
# 맛난것 먹기
# 아무것도 안하기
# 좋은 사람 만나기

# %%
schedule.values
# Out:
# array(['음악듣기', '책읽기', '맛난것 먹기', '아무것도 안하기', '좋은 사람 만나기'], dtype=object)

# %%
schedule.values
# Out:
# array(['음악듣기', '책읽기', '맛난것 먹기', '아무것도 안하기', '좋은 사람 만나기'], dtype=object)

# %%
schedule.index
# Out:
# DatetimeIndex(['2021-06-21', '2021-06-22', '2021-06-23', '2021-06-24',
#                '2021-06-25'],
#               dtype='datetime64[ns]', freq='D')

# %%
for idx in schedule.index:
    print(idx)
# Out:
# 2021-06-21 00:00:00
# 2021-06-22 00:00:00
# 2021-06-23 00:00:00
# 2021-06-24 00:00:00
# 2021-06-25 00:00:00

# %%
from pandas import DataFrame

# %%
dat = { 'col1' : [1,2,3,4],
        'col2' : [10,20,30,40],
        'col3' : ['A', 'B', 'C', 'D'] }
df = DataFrame(dat)
df
# Out:
#    col1  col2 col3
# 0     1    10    A
# 1     2    20    B
# 2     3    30    C
# 3     4    40    D

# %%
from pandas import DataFrame
team_score = { "toto":[1500,3000,5000,7000,5500],
              "apple":[4000,5000,6000,5500,4500],
              "gildong":[2000,2500,3000,4000,3000],
              "catanddog":[7000,5000,3000,5000,4000]}
team_df = DataFrame(team_score)
team_df
# Out:
#    toto  apple  gildong  catanddog
# 0  1500   4000     2000       7000
# 1  3000   5000     2500       5000
# 2  5000   6000     3000       3000
# 3  7000   5500     4000       5000
# 4  5500   4500     3000       4000

# %%
idx = pd.date_range(start="2021-06-21", end="2021-06-25")
idx
# Out:
# DatetimeIndex(['2021-06-21', '2021-06-22', '2021-06-23', '2021-06-24',
#                '2021-06-25'],
#               dtype='datetime64[ns]', freq='D')

# %%
team_df = DataFrame(team_score,columns=['catanddog', 'toto', 'apple', 'gildong'],index=date)
team_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-bc0b87189c45> in <module>
# ----> 1 team_df = DataFrame(team_score,columns=['catanddog', 'toto', 'apple', 'gildong'],index=date)
#       2 team_df
#
# NameError: name 'date' is not defined

# %%
from pandas import DataFrame
team_score = { "toto":[1500,3000,5000,7000,5500],
              "apple":[4000,5000,6000,5500,4500],
              "gildong":[2000,2500,3000,4000,3000],
              "catanddog":[7000,5000,3000,5000,4000]}
team_df = DataFrame(team_score, index=idx)
team_df






from pandas import DataFrame
idx = pd.date_range(start="2021-06-21", end="2021-06-25")
team_score = { "toto":[1500,3000,5000,7000,5500],
              "apple":[4000,5000,6000,5500,4500],
              "gildong":[2000,2500,3000,4000,3000],
              "catanddog":[7000,5000,3000,5000,4000]}
team_df = DataFrame(team_score, index=idx)
team_df
# Out:
#             toto  apple  gildong  catanddog
# 2021-06-21  1500   4000     2000       7000
# 2021-06-22  3000   5000     2500       5000
# 2021-06-23  5000   6000     3000       3000
# 2021-06-24  7000   5500     4000       5000
# 2021-06-25  5500   4500     3000       4000

# %%
team_df.index
# Out:
# DatetimeIndex(['2021-06-21', '2021-06-22', '2021-06-23', '2021-06-24',
#                '2021-06-25'],
#               dtype='datetime64[ns]', freq='D')

# %%
team_df.columns
# Out:
# Index(['toto', 'apple', 'gildong', 'catanddog'], dtype='object')

# %%
team_df.loc[:,'toto']
# Out:
# 2021-06-21    1500
# 2021-06-22    3000
# 2021-06-23    5000
# 2021-06-24    7000
# 2021-06-25    5500
# Freq: D, Name: toto, dtype: int64

# %%
team_df.loc[:, :'apple']
# Out:
#             toto  apple
# 2021-06-21  1500   4000
# 2021-06-22  3000   5000
# 2021-06-23  5000   6000
# 2021-06-24  7000   5500
# 2021-06-25  5500   4500

# %%
team_df.loc['2021-06-21':'2021-06-23',:]
# Out:
#             toto  apple  gildong  catanddog
# 2021-06-21  1500   4000     2000       7000
# 2021-06-22  3000   5000     2500       5000
# 2021-06-23  5000   6000     3000       3000

# %%
team_df.iloc[:,2]
# Out:
# 2021-06-21    2000
# 2021-06-22    2500
# 2021-06-23    3000
# 2021-06-24    4000
# 2021-06-25    3000
# Freq: D, Name: gildong, dtype: int64

# %%
team_df.iloc[:,2:4]
# Out:
#             gildong  catanddog
# 2021-06-21     2000       7000
# 2021-06-22     2500       5000
# 2021-06-23     3000       3000
# 2021-06-24     4000       5000
# 2021-06-25     3000       4000

# %%
team_df['toto']
# Out:
# 2021-06-21    1500
# 2021-06-22    3000
# 2021-06-23    5000
# 2021-06-24    7000
# 2021-06-25    5500
# Freq: D, Name: toto, dtype: int64

# %%
team_df['toto':'gildong']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string_with_reso()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.dateutil_parse()
#
# ValueError: Unknown datetime string format, unable to parse: toto
#
# During handling of the above exception, another exception occurred:
#
# DateParseError                            Traceback (most recent call last)
# <ipython-input-104-a87e7cc77fba> in <module>
# ----> 1 team_df['toto':'gildong']
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2879
#    2880         # Do we have a slicer (on rows)?
# -> 2881         indexer = convert_to_index_sliceable(self, key)
#    2882         if indexer is not None:
#    2883             # either we have a slice or we have a string that can be converted
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in convert_to_index_sliceable(obj, key)
#    2132     idx = obj.index
#    2133     if isinstance(key, slice):
# -> 2134         return idx._convert_slice_indexer(key, kind="getitem")
#    2135
#    2136     elif isinstance(key, str):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in _convert_slice_indexer(self, key, kind)
#    3188             indexer = key
#    3189         else:
# -> 3190             indexer = self.slice_indexer(start, stop, step, kind=kind)
#    3191
#    3192         return indexer
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/datetimes.py in slice_indexer(self, start, end, step, kind)
#     716
#     717         try:
# --> 718             return Index.slice_indexer(self, start, end, step, kind=kind)
#     719         except KeyError:
#     720             # For historical reasons DatetimeIndex by default supports
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in slice_indexer(self, start, end, step, kind)
#    4964         slice(1, 3, None)
#    4965         """
# -> 4966         start_slice, end_slice = self.slice_locs(start, end, step=step, kind=kind)
#    4967
#    4968         # return a slice
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in slice_locs(self, start, end, step, kind)
#    5165         start_slice = None
#    5166         if start is not None:
# -> 5167             start_slice = self.get_slice_bound(start, "left", kind)
#    5168         if start_slice is None:
#    5169             start_slice = 0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side, kind)
#    5077         # For datetime indices label may be a string that has to be converted
#    5078         # to datetime boundary according to its resolution.
# -> 5079         label = self._maybe_cast_slice_bound(label, side, kind)
#    5080
#    5081         # we need to look up the label
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/datetimes.py in _maybe_cast_slice_bound(self, label, side, kind)
#     661         if isinstance(label, str):
#     662             freq = getattr(self, "freqstr", getattr(self, "inferred_freq", None))
# --> 663             parsed, reso = parsing.parse_time_string(label, freq)
#     664             reso = Resolution.from_attrname(reso)
#     665             lower, upper = self._parsed_string_to_bounds(reso, parsed)
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_time_string()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string_with_reso()
#
# DateParseError: Unknown datetime string format, unable to parse: toto

# %%
team_df.loc[ :, ['toto','gildong']]
# Out:
#             toto  gildong
# 2021-06-21  1500     2000
# 2021-06-22  3000     2500
# 2021-06-23  5000     3000
# 2021-06-24  7000     4000
# 2021-06-25  5500     3000

# %%
team_df[ ['toto','gildong']]
# Out:
#             toto  gildong
# 2021-06-21  1500     2000
# 2021-06-22  3000     2500
# 2021-06-23  5000     3000
# 2021-06-24  7000     4000
# 2021-06-25  5500     3000

# %%
print(team_df.iloc[0:3:1])
# Out:
#             toto  apple  gildong  catanddog
# 2021-06-21  1500   4000     2000       7000
# 2021-06-22  3000   5000     2500       5000
# 2021-06-23  5000   6000     3000       3000

# %%
print(team_df.loc['2021-06-21'])
# Out:
# toto         1500
# apple        4000
# gildong      2000
# catanddog    7000
# Name: 2021-06-21 00:00:00, dtype: int64

# %%
print(team_df.sum() )
print("----")
print(team_df.mean() ) 
print("----")
# Out:
# toto         22000
# apple        25000
# gildong      14500
# catanddog    24000
# dtype: int64
# ----
# toto         4400.0
# apple        5000.0
# gildong      2900.0
# catanddog    4800.0
# dtype: float64
# ----

# %%
team_df['rowsum'] = team_df.sum(axis=1)
team_df
# Out:
#             toto  apple  gildong  catanddog  rowsum
# 2021-06-21  1500   4000     2000       7000   14500
# 2021-06-22  3000   5000     2500       5000   15500
# 2021-06-23  5000   6000     3000       3000   17000
# 2021-06-24  7000   5500     4000       5000   21500
# 2021-06-25  5500   4500     3000       4000   17000

# %%
dat = { "순위":[1,2,3,4],
        "연속":[2,1,1,1],
        "누적":[2,3,2,4],
        "종목명":["솔고바이오", "한세엠케이", "네오오토", "엄지하우스"],
        "현재가":[933,9490, 9990, 4885],
        "전일비":[229, 2190, 2300, 635],
        "등락률":[29.97, 30.00, 29.91, 14.94],
        "거래량":[4657527, 19568672, 3157505, 7231]}
index = Date_range('2021')
dat_df = pd.DataFrame(dat)
dat_df
# Out:
#    순위  연속  누적    종목명   현재가   전일비    등락률       거래량
# 0   1   2   2  솔고바이오   933   229  29.97   4657527
# 1   2   1   3  한세엠케이  9490  2190  30.00  19568672
# 2   3   1   2   네오오토  9990  2300  29.91   3157505
# 3   4   1   4  엄지하우스  4885   635  14.94      7231

# %%
dat_df['종목명']
# Out:
# 0    솔고바이오
# 1    한세엠케이
# 2     네오오토
# 3    엄지하우스
# Name: 종목명, dtype: object
